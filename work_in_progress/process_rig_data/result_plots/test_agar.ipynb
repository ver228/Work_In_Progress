# %%
# %matplotlib inline
import os
import matplotlib.pylab as plt

from plot_db import plot_db
DATABASE_DIR = '/Users/ajaver/OneDrive - Imperial College London/compare_strains_DB'

tab_name = 'features_medians_split'
filt_path_range = 0
filt_frac_good = 0

# %%
database_name = 'control_experiments_Agar_Test.db'
db_path = os.path.join(DATABASE_DIR, database_name)
db_agar = plot_db(db_path, filt_path_range, filt_frac_good, tab_name)
valid_rows = (db_agar.feats['n_frames'] > 1000)

# %%
#% Agar_Screening_181116 seems to be wrongly labeled
db_agar.plot(['length',  'Strain', 'Old/New Agar', 'exp_name'], [], valid_rows)
#db_agar.plot(['midbody_speed_pos',  'Strain', 'Old/New Agar', 'exp_name'], [])
