# %%
# %matplotlib inline
import os
import matplotlib.pylab as plt

from plot_db import plot_db
DATABASE_DIR = '/Users/ajaver/OneDrive - Imperial College London/compare_strains_DB'

tab_name = 'features_medians_split'
filt_path_range = 0
filt_frac_good = 0

# %%
database_name = 'control_experiments_Test_Food.db'
db_path = os.path.join(DATABASE_DIR, database_name)
food_db = plot_db(db_path, filt_path_range, filt_frac_good, tab_name)

# %%
 #in this data set there are very 'fast' particles with short trajectories (likely errors)  
valid_rows = (food_db.feats['n_frames'] > 1000)
food_db.plot(['length',  'Strain', 'Picker'], [], valid_rows)
food_db.plot(['midbody_speed_pos',  'Strain', 'Food_Conc'], [], valid_rows)
plt.title('Food concentration')

# %%
valid_rows = None 
food_db.plot(['length',  'Strain', 'Picker'], [], valid_rows)

valid_rows = (food_db.feats['n_frames'] > 1000)
food_db.plot(['length',  'Strain', 'Picker'], [], valid_rows)
