# %%
# %matplotlib inline
import os
import matplotlib.pylab as plt

from plot_db import plot_db
DATABASE_DIR = '/Users/ajaver/OneDrive - Imperial College London/compare_strains_DB'

tab_name = 'features_means'
filt_path_range = 0
filt_frac_good = 0

database_name = 'control_single.db'
db_path = os.path.join(DATABASE_DIR, database_name)
db_old = plot_db(db_path, filt_path_range, filt_frac_good, tab_name)

#select worms that are none 
chg = (db_old.feats['gene']!=db_old.feats['gene']) 
db_old.feats.loc[chg, 'gene'] = 'N2'
db_old.feats = db_old.feats.sort_values(by='gene', ascending=False)
db_old.feats = db_old.feats.rename(columns={'gene':'Strain'})

# %%
db_old.plot(['length',  'Strain'])
db_old.plot(['midbody_speed_pos',  'Strain'])
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
