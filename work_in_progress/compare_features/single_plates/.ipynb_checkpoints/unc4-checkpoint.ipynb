# %%
# %matplotlib inline

import os
import glob
import pandas as pd
import seaborn as sns

results_dir = '/Volumes/behavgenom_archive$/Avelino/test_unc-4/310317/Results/'

assert os.path.exists(results_dir)
feature_files = glob.glob(os.path.join(results_dir, '*_features.hdf5'))

medians_split = pd.DataFrame()

for feat_file in feature_files:
    base_name = os.path.basename(feat_file).replace('_features.hdf5', '')
    base_name = base_name.partition('_Ch1')[0]
    print(base_name)
    with pd.HDFStore(feat_file, 'r') as fid:
        tab = fid['/features_summary/medians_split']
        tab['base_name'] = base_name
        medians_split = pd.concat([medians_split, tab])
# Out:
# L4_unc4(e2323)

# %%
index_cols = ['worm_index', 'n_frames', 'n_valid_skel', 'first_frame', 'base_name']
feat_cols = [x for x in medians_split.columns if x not in index_cols]

for col in feat_cols:
    print(col)
grouped = medians_split.groupby('base_name')
# Out:
# worm_dwelling
# head_dwelling
# midbody_dwelling
# tail_dwelling
# length
# length_foward
# length_paused
# length_backward
# head_width
# head_width_foward
# head_width_paused
# head_width_backward
# midbody_width
# midbody_width_foward
# midbody_width_paused
# midbody_width_backward
# tail_width
# tail_width_foward
# tail_width_paused
# tail_width_backward
# area
# area_foward
# area_paused
# area_backward
# area_length_ratio
# area_length_ratio_foward
# area_length_ratio_paused
# area_length_ratio_backward
# width_length_ratio
# width_length_ratio_foward
# width_length_ratio_paused
# width_length_ratio_backward
# head_bend_mean
# head_bend_mean_abs
# head_bend_mean_neg
# head_bend_mean_pos
# head_bend_mean_foward
# head_bend_mean_foward_abs
# head_bend_mean_foward_neg
# head_bend_mean_foward_pos
# head_bend_mean_paused
# head_bend_mean_paused_abs
# head_bend_mean_paused_neg
# head_bend_mean_paused_pos
# head_bend_mean_backward
# head_bend_mean_backward_abs
# head_bend_mean_backward_neg
# head_bend_mean_backward_pos
# neck_bend_mean
# neck_bend_mean_abs
# neck_bend_mean_neg
# neck_bend_mean_pos
# neck_bend_mean_foward
# neck_bend_mean_foward_abs
# neck_bend_mean_foward_neg
# neck_bend_mean_foward_pos
# neck_bend_mean_paused
# neck_bend_mean_paused_abs
# neck_bend_mean_paused_neg
# neck_bend_mean_paused_pos
# neck_bend_mean_backward
# neck_bend_mean_backward_abs
# neck_bend_mean_backward_neg
# neck_bend_mean_backward_pos
# midbody_bend_mean
# midbody_bend_mean_abs
# midbody_bend_mean_neg
# midbody_bend_mean_pos
# midbody_bend_mean_foward
# midbody_bend_mean_foward_abs
# midbody_bend_mean_foward_neg
# midbody_bend_mean_foward_pos
# midbody_bend_mean_paused
# midbody_bend_mean_paused_abs
# midbody_bend_mean_paused_neg
# midbody_bend_mean_paused_pos
# midbody_bend_mean_backward
# midbody_bend_mean_backward_abs
# midbody_bend_mean_backward_neg
# midbody_bend_mean_backward_pos
# hips_bend_mean
# hips_bend_mean_abs
# hips_bend_mean_neg
# hips_bend_mean_pos
# hips_bend_mean_foward
# hips_bend_mean_foward_abs
# hips_bend_mean_foward_neg
# hips_bend_mean_foward_pos
# hips_bend_mean_paused
# hips_bend_mean_paused_abs
# hips_bend_mean_paused_neg
# hips_bend_mean_paused_pos
# hips_bend_mean_backward
# hips_bend_mean_backward_abs
# hips_bend_mean_backward_neg
# hips_bend_mean_backward_pos
# tail_bend_mean
# tail_bend_mean_abs
# tail_bend_mean_neg
# tail_bend_mean_pos
# tail_bend_mean_foward
# tail_bend_mean_foward_abs
# tail_bend_mean_foward_neg
# tail_bend_mean_foward_pos
# tail_bend_mean_paused
# tail_bend_mean_paused_abs
# tail_bend_mean_paused_neg
# tail_bend_mean_paused_pos
# tail_bend_mean_backward
# tail_bend_mean_backward_abs
# tail_bend_mean_backward_neg
# tail_bend_mean_backward_pos
# head_bend_sd
# head_bend_sd_abs
# head_bend_sd_neg
# head_bend_sd_pos
# head_bend_sd_foward
# head_bend_sd_foward_abs
# head_bend_sd_foward_neg
# head_bend_sd_foward_pos
# head_bend_sd_paused
# head_bend_sd_paused_abs
# head_bend_sd_paused_neg
# head_bend_sd_paused_pos
# head_bend_sd_backward
# head_bend_sd_backward_abs
# head_bend_sd_backward_neg
# head_bend_sd_backward_pos
# neck_bend_sd
# neck_bend_sd_abs
# neck_bend_sd_neg
# neck_bend_sd_pos
# neck_bend_sd_foward
# neck_bend_sd_foward_abs
# neck_bend_sd_foward_neg
# neck_bend_sd_foward_pos
# neck_bend_sd_paused
# neck_bend_sd_paused_abs
# neck_bend_sd_paused_neg
# neck_bend_sd_paused_pos
# neck_bend_sd_backward
# neck_bend_sd_backward_abs
# neck_bend_sd_backward_neg
# neck_bend_sd_backward_pos
# midbody_bend_sd
# midbody_bend_sd_abs
# midbody_bend_sd_neg
# midbody_bend_sd_pos
# midbody_bend_sd_foward
# midbody_bend_sd_foward_abs
# midbody_bend_sd_foward_neg
# midbody_bend_sd_foward_pos
# midbody_bend_sd_paused
# midbody_bend_sd_paused_abs
# midbody_bend_sd_paused_neg
# midbody_bend_sd_paused_pos
# midbody_bend_sd_backward
# midbody_bend_sd_backward_abs
# midbody_bend_sd_backward_neg
# midbody_bend_sd_backward_pos
# hips_bend_sd
# hips_bend_sd_abs
# hips_bend_sd_neg
# hips_bend_sd_pos
# hips_bend_sd_foward
# hips_bend_sd_foward_abs
# hips_bend_sd_foward_neg
# hips_bend_sd_foward_pos
# hips_bend_sd_paused
# hips_bend_sd_paused_abs
# hips_bend_sd_paused_neg
# hips_bend_sd_paused_pos
# hips_bend_sd_backward
# hips_bend_sd_backward_abs
# hips_bend_sd_backward_neg
# hips_bend_sd_backward_pos
# tail_bend_sd
# tail_bend_sd_abs
# tail_bend_sd_neg
# tail_bend_sd_pos
# tail_bend_sd_foward
# tail_bend_sd_foward_abs
# tail_bend_sd_foward_neg
# tail_bend_sd_foward_pos
# tail_bend_sd_paused
# tail_bend_sd_paused_abs
# tail_bend_sd_paused_neg
# tail_bend_sd_paused_pos
# tail_bend_sd_backward
# tail_bend_sd_backward_abs
# tail_bend_sd_backward_neg
# tail_bend_sd_backward_pos
# max_amplitude
# max_amplitude_foward
# max_amplitude_paused
# max_amplitude_backward
# amplitude_ratio
# amplitude_ratio_foward
# amplitude_ratio_paused
# amplitude_ratio_backward
# primary_wavelength
# primary_wavelength_foward
# primary_wavelength_paused
# primary_wavelength_backward
# secondary_wavelength
# secondary_wavelength_foward
# secondary_wavelength_paused
# secondary_wavelength_backward
# track_length
# track_length_foward
# track_length_paused
# track_length_backward
# eccentricity
# eccentricity_foward
# eccentricity_paused
# eccentricity_backward
# bend_count
# bend_count_foward
# bend_count_paused
# bend_count_backward
# tail_to_head_orientation
# tail_to_head_orientation_abs
# tail_to_head_orientation_neg
# tail_to_head_orientation_pos
# tail_to_head_orientation_foward
# tail_to_head_orientation_foward_abs
# tail_to_head_orientation_foward_neg
# tail_to_head_orientation_foward_pos
# tail_to_head_orientation_paused
# tail_to_head_orientation_paused_abs
# tail_to_head_orientation_paused_neg
# tail_to_head_orientation_paused_pos
# tail_to_head_orientation_backward
# tail_to_head_orientation_backward_abs
# tail_to_head_orientation_backward_neg
# tail_to_head_orientation_backward_pos
# head_orientation
# head_orientation_abs
# head_orientation_neg
# head_orientation_pos
# head_orientation_foward
# head_orientation_foward_abs
# head_orientation_foward_neg
# head_orientation_foward_pos
# head_orientation_paused
# head_orientation_paused_abs
# head_orientation_paused_neg
# head_orientation_paused_pos
# head_orientation_backward
# head_orientation_backward_abs
# head_orientation_backward_neg
# head_orientation_backward_pos
# tail_orientation
# tail_orientation_abs
# tail_orientation_neg
# tail_orientation_pos
# tail_orientation_foward
# tail_orientation_foward_abs
# tail_orientation_foward_neg
# tail_orientation_foward_pos
# tail_orientation_paused
# tail_orientation_paused_abs
# tail_orientation_paused_neg
# tail_orientation_paused_pos
# tail_orientation_backward
# tail_orientation_backward_abs
# tail_orientation_backward_neg
# tail_orientation_backward_pos
# eigen_projection_1
# eigen_projection_1_abs
# eigen_projection_1_neg
# eigen_projection_1_pos
# eigen_projection_1_foward
# eigen_projection_1_foward_abs
# eigen_projection_1_foward_neg
# eigen_projection_1_foward_pos
# eigen_projection_1_paused
# eigen_projection_1_paused_abs
# eigen_projection_1_paused_neg
# eigen_projection_1_paused_pos
# eigen_projection_1_backward
# eigen_projection_1_backward_abs
# eigen_projection_1_backward_neg
# eigen_projection_1_backward_pos
# eigen_projection_2
# eigen_projection_2_abs
# eigen_projection_2_neg
# eigen_projection_2_pos
# eigen_projection_2_foward
# eigen_projection_2_foward_abs
# eigen_projection_2_foward_neg
# eigen_projection_2_foward_pos
# eigen_projection_2_paused
# eigen_projection_2_paused_abs
# eigen_projection_2_paused_neg
# eigen_projection_2_paused_pos
# eigen_projection_2_backward
# eigen_projection_2_backward_abs
# eigen_projection_2_backward_neg
# eigen_projection_2_backward_pos
# eigen_projection_3
# eigen_projection_3_abs
# eigen_projection_3_neg
# eigen_projection_3_pos
# eigen_projection_3_foward
# eigen_projection_3_foward_abs
# eigen_projection_3_foward_neg
# eigen_projection_3_foward_pos
# eigen_projection_3_paused
# eigen_projection_3_paused_abs
# eigen_projection_3_paused_neg
# eigen_projection_3_paused_pos
# eigen_projection_3_backward
# eigen_projection_3_backward_abs
# eigen_projection_3_backward_neg
# eigen_projection_3_backward_pos
# eigen_projection_4
# eigen_projection_4_abs
# eigen_projection_4_neg
# eigen_projection_4_pos
# eigen_projection_4_foward
# eigen_projection_4_foward_abs
# eigen_projection_4_foward_neg
# eigen_projection_4_foward_pos
# eigen_projection_4_paused
# eigen_projection_4_paused_abs
# eigen_projection_4_paused_neg
# eigen_projection_4_paused_pos
# eigen_projection_4_backward
# eigen_projection_4_backward_abs
# eigen_projection_4_backward_neg
# eigen_projection_4_backward_pos
# eigen_projection_5
# eigen_projection_5_abs
# eigen_projection_5_neg
# eigen_projection_5_pos
# eigen_projection_5_foward
# eigen_projection_5_foward_abs
# eigen_projection_5_foward_neg
# eigen_projection_5_foward_pos
# eigen_projection_5_paused
# eigen_projection_5_paused_abs
# eigen_projection_5_paused_neg
# eigen_projection_5_paused_pos
# eigen_projection_5_backward
# eigen_projection_5_backward_abs
# eigen_projection_5_backward_neg
# eigen_projection_5_backward_pos
# eigen_projection_6
# eigen_projection_6_abs
# eigen_projection_6_neg
# eigen_projection_6_pos
# eigen_projection_6_foward
# eigen_projection_6_foward_abs
# eigen_projection_6_foward_neg
# eigen_projection_6_foward_pos
# eigen_projection_6_paused
# eigen_projection_6_paused_abs
# eigen_projection_6_paused_neg
# eigen_projection_6_paused_pos
# eigen_projection_6_backward
# eigen_projection_6_backward_abs
# eigen_projection_6_backward_neg
# eigen_projection_6_backward_pos
# head_tip_speed
# head_tip_speed_abs
# head_tip_speed_neg
# head_tip_speed_pos
# head_tip_speed_foward
# head_tip_speed_foward_abs
# head_tip_speed_foward_neg
# head_tip_speed_foward_pos
# head_tip_speed_paused
# head_tip_speed_paused_abs
# head_tip_speed_paused_neg
# head_tip_speed_paused_pos
# head_tip_speed_backward
# head_tip_speed_backward_abs
# head_tip_speed_backward_neg
# head_tip_speed_backward_pos
# head_speed
# head_speed_abs
# head_speed_neg
# head_speed_pos
# head_speed_foward
# head_speed_foward_abs
# head_speed_foward_neg
# head_speed_foward_pos
# head_speed_paused
# head_speed_paused_abs
# head_speed_paused_neg
# head_speed_paused_pos
# head_speed_backward
# head_speed_backward_abs
# head_speed_backward_neg
# head_speed_backward_pos
# midbody_speed
# midbody_speed_abs
# midbody_speed_neg
# midbody_speed_pos
# midbody_speed_foward
# midbody_speed_foward_abs
# midbody_speed_foward_neg
# midbody_speed_foward_pos
# midbody_speed_paused
# midbody_speed_paused_abs
# midbody_speed_paused_neg
# midbody_speed_paused_pos
# midbody_speed_backward
# midbody_speed_backward_abs
# midbody_speed_backward_neg
# midbody_speed_backward_pos
# tail_speed
# tail_speed_abs
# tail_speed_neg
# tail_speed_pos
# tail_speed_foward
# tail_speed_foward_abs
# tail_speed_foward_neg
# tail_speed_foward_pos
# tail_speed_paused
# tail_speed_paused_abs
# tail_speed_paused_neg
# tail_speed_paused_pos
# tail_speed_backward
# tail_speed_backward_abs
# tail_speed_backward_neg
# tail_speed_backward_pos
# tail_tip_speed
# tail_tip_speed_abs
# tail_tip_speed_neg
# tail_tip_speed_pos
# tail_tip_speed_foward
# tail_tip_speed_foward_abs
# tail_tip_speed_foward_neg
# tail_tip_speed_foward_pos
# tail_tip_speed_paused
# tail_tip_speed_paused_abs
# tail_tip_speed_paused_neg
# tail_tip_speed_paused_pos
# tail_tip_speed_backward
# tail_tip_speed_backward_abs
# tail_tip_speed_backward_neg
# tail_tip_speed_backward_pos
# head_tip_motion_direction
# head_tip_motion_direction_abs
# head_tip_motion_direction_neg
# head_tip_motion_direction_pos
# head_tip_motion_direction_foward
# head_tip_motion_direction_foward_abs
# head_tip_motion_direction_foward_neg
# head_tip_motion_direction_foward_pos
# head_tip_motion_direction_paused
# head_tip_motion_direction_paused_abs
# head_tip_motion_direction_paused_neg
# head_tip_motion_direction_paused_pos
# head_tip_motion_direction_backward
# head_tip_motion_direction_backward_abs
# head_tip_motion_direction_backward_neg
# head_tip_motion_direction_backward_pos
# head_motion_direction
# head_motion_direction_abs
# head_motion_direction_neg
# head_motion_direction_pos
# head_motion_direction_foward
# head_motion_direction_foward_abs
# head_motion_direction_foward_neg
# head_motion_direction_foward_pos
# head_motion_direction_paused
# head_motion_direction_paused_abs
# head_motion_direction_paused_neg
# head_motion_direction_paused_pos
# head_motion_direction_backward
# head_motion_direction_backward_abs
# head_motion_direction_backward_neg
# head_motion_direction_backward_pos
# midbody_motion_direction
# midbody_motion_direction_abs
# midbody_motion_direction_neg
# midbody_motion_direction_pos
# midbody_motion_direction_foward
# midbody_motion_direction_foward_abs
# midbody_motion_direction_foward_neg
# midbody_motion_direction_foward_pos
# midbody_motion_direction_paused
# midbody_motion_direction_paused_abs
# midbody_motion_direction_paused_neg
# midbody_motion_direction_paused_pos
# midbody_motion_direction_backward
# midbody_motion_direction_backward_abs
# midbody_motion_direction_backward_neg
# midbody_motion_direction_backward_pos
# tail_motion_direction
# tail_motion_direction_abs
# tail_motion_direction_neg
# tail_motion_direction_pos
# tail_motion_direction_foward
# tail_motion_direction_foward_abs
# tail_motion_direction_foward_neg
# tail_motion_direction_foward_pos
# tail_motion_direction_paused
# tail_motion_direction_paused_abs
# tail_motion_direction_paused_neg
# tail_motion_direction_paused_pos
# tail_motion_direction_backward
# tail_motion_direction_backward_abs
# tail_motion_direction_backward_neg
# tail_motion_direction_backward_pos
# tail_tip_motion_direction
# tail_tip_motion_direction_abs
# tail_tip_motion_direction_neg
# tail_tip_motion_direction_pos
# tail_tip_motion_direction_foward
# tail_tip_motion_direction_foward_abs
# tail_tip_motion_direction_foward_neg
# tail_tip_motion_direction_foward_pos
# tail_tip_motion_direction_paused
# tail_tip_motion_direction_paused_abs
# tail_tip_motion_direction_paused_neg
# tail_tip_motion_direction_paused_pos
# tail_tip_motion_direction_backward
# tail_tip_motion_direction_backward_abs
# tail_tip_motion_direction_backward_neg
# tail_tip_motion_direction_backward_pos
# foraging_amplitude
# foraging_amplitude_abs
# foraging_amplitude_neg
# foraging_amplitude_pos
# foraging_amplitude_foward
# foraging_amplitude_foward_abs
# foraging_amplitude_foward_neg
# foraging_amplitude_foward_pos
# foraging_amplitude_paused
# foraging_amplitude_paused_abs
# foraging_amplitude_paused_neg
# foraging_amplitude_paused_pos
# foraging_amplitude_backward
# foraging_amplitude_backward_abs
# foraging_amplitude_backward_neg
# foraging_amplitude_backward_pos
# foraging_speed
# foraging_speed_abs
# foraging_speed_neg
# foraging_speed_pos
# foraging_speed_foward
# foraging_speed_foward_abs
# foraging_speed_foward_neg
# foraging_speed_foward_pos
# foraging_speed_paused
# foraging_speed_paused_abs
# foraging_speed_paused_neg
# foraging_speed_paused_pos
# foraging_speed_backward
# foraging_speed_backward_abs
# foraging_speed_backward_neg
# foraging_speed_backward_pos
# head_crawling_amplitude
# head_crawling_amplitude_abs
# head_crawling_amplitude_neg
# head_crawling_amplitude_pos
# head_crawling_amplitude_foward
# head_crawling_amplitude_foward_abs
# head_crawling_amplitude_foward_neg
# head_crawling_amplitude_foward_pos
# head_crawling_amplitude_paused
# head_crawling_amplitude_paused_abs
# head_crawling_amplitude_paused_neg
# head_crawling_amplitude_paused_pos
# head_crawling_amplitude_backward
# head_crawling_amplitude_backward_abs
# head_crawling_amplitude_backward_neg
# head_crawling_amplitude_backward_pos
# midbody_crawling_amplitude
# midbody_crawling_amplitude_abs
# midbody_crawling_amplitude_neg
# midbody_crawling_amplitude_pos
# midbody_crawling_amplitude_foward
# midbody_crawling_amplitude_foward_abs
# midbody_crawling_amplitude_foward_neg
# midbody_crawling_amplitude_foward_pos
# midbody_crawling_amplitude_paused
# midbody_crawling_amplitude_paused_abs
# midbody_crawling_amplitude_paused_neg
# midbody_crawling_amplitude_paused_pos
# midbody_crawling_amplitude_backward
# midbody_crawling_amplitude_backward_abs
# midbody_crawling_amplitude_backward_neg
# midbody_crawling_amplitude_backward_pos
# tail_crawling_amplitude
# tail_crawling_amplitude_abs
# tail_crawling_amplitude_neg
# tail_crawling_amplitude_pos
# tail_crawling_amplitude_foward
# tail_crawling_amplitude_foward_abs
# tail_crawling_amplitude_foward_neg
# tail_crawling_amplitude_foward_pos
# tail_crawling_amplitude_paused
# tail_crawling_amplitude_paused_abs
# tail_crawling_amplitude_paused_neg
# tail_crawling_amplitude_paused_pos
# tail_crawling_amplitude_backward
# tail_crawling_amplitude_backward_abs
# tail_crawling_amplitude_backward_neg
# tail_crawling_amplitude_backward_pos
# head_crawling_frequency
# head_crawling_frequency_abs
# head_crawling_frequency_neg
# head_crawling_frequency_pos
# head_crawling_frequency_foward
# head_crawling_frequency_foward_abs
# head_crawling_frequency_foward_neg
# head_crawling_frequency_foward_pos
# head_crawling_frequency_paused
# head_crawling_frequency_paused_abs
# head_crawling_frequency_paused_neg
# head_crawling_frequency_paused_pos
# head_crawling_frequency_backward
# head_crawling_frequency_backward_abs
# head_crawling_frequency_backward_neg
# head_crawling_frequency_backward_pos
# midbody_crawling_frequency
# midbody_crawling_frequency_abs
# midbody_crawling_frequency_neg
# midbody_crawling_frequency_pos
# midbody_crawling_frequency_foward
# midbody_crawling_frequency_foward_abs
# midbody_crawling_frequency_foward_neg
# midbody_crawling_frequency_foward_pos
# midbody_crawling_frequency_paused
# midbody_crawling_frequency_paused_abs
# midbody_crawling_frequency_paused_neg
# midbody_crawling_frequency_paused_pos
# midbody_crawling_frequency_backward
# midbody_crawling_frequency_backward_abs
# midbody_crawling_frequency_backward_neg
# midbody_crawling_frequency_backward_pos
# tail_crawling_frequency
# tail_crawling_frequency_abs
# tail_crawling_frequency_neg
# tail_crawling_frequency_pos
# tail_crawling_frequency_foward
# tail_crawling_frequency_foward_abs
# tail_crawling_frequency_foward_neg
# tail_crawling_frequency_foward_pos
# tail_crawling_frequency_paused
# tail_crawling_frequency_paused_abs
# tail_crawling_frequency_paused_neg
# tail_crawling_frequency_paused_pos
# tail_crawling_frequency_backward
# tail_crawling_frequency_backward_abs
# tail_crawling_frequency_backward_neg
# tail_crawling_frequency_backward_pos
# path_range
# path_range_foward
# path_range_paused
# path_range_backward
# path_curvature
# path_curvature_abs
# path_curvature_neg
# path_curvature_pos
# path_curvature_foward
# path_curvature_foward_abs
# path_curvature_foward_neg
# path_curvature_foward_pos
# path_curvature_paused
# path_curvature_paused_abs
# path_curvature_paused_neg
# path_curvature_paused_pos
# path_curvature_backward
# path_curvature_backward_abs
# path_curvature_backward_neg
# path_curvature_backward_pos
# coil_time
# inter_coil_time
# inter_coil_distance
# coils_frequency
# coils_time_ratio
# omega_turn_time
# omega_turn_time_abs
# omega_turn_time_neg
# omega_turn_time_pos
# inter_omega_time
# inter_omega_time_abs
# inter_omega_time_neg
# inter_omega_time_pos
# inter_omega_distance
# inter_omega_distance_abs
# inter_omega_distance_neg
# inter_omega_distance_pos
# omega_turns_frequency
# omega_turns_time_ratio
# upsilon_turn_time
# upsilon_turn_time_abs
# upsilon_turn_time_neg
# upsilon_turn_time_pos
# inter_upsilon_time
# inter_upsilon_time_abs
# inter_upsilon_time_neg
# inter_upsilon_time_pos
# inter_upsilon_distance
# inter_upsilon_distance_abs
# inter_upsilon_distance_neg
# inter_upsilon_distance_pos
# upsilon_turns_frequency
# upsilon_turns_time_ratio
# forward_time
# forward_distance
# inter_forward_time
# inter_forward_distance
# forward_motion_frequency
# forward_motion_time_ratio
# forward_motion_distance_ratio
# paused_time
# paused_distance
# inter_paused_time
# inter_paused_distance
# paused_motion_frequency
# paused_motion_time_ratio
# paused_motion_distance_ratio
# backward_time
# backward_distance
# inter_backward_time
# inter_backward_distance
# backward_motion_frequency
# backward_motion_time_ratio
# backward_motion_distance_ratio

# %%
with pd.option_context('display.max_rows', None):
    print(medians_split[['base_name', 'worm_index', 'n_frames', 'head_dwelling']])
# Out:
#               base_name  worm_index  n_frames  head_dwelling
# 0        L4_unc4(e2323)         2.0     952.0       0.797522
# 1        L4_unc4(e2323)         3.0    7500.0       0.805381
# 2        L4_unc4(e2323)         3.0    2400.0       0.855591
# 3        L4_unc4(e2323)         7.0    7500.0     121.160004
# 4        L4_unc4(e2323)         7.0    7500.0     115.510773
# 5        L4_unc4(e2323)         7.0    7500.0      18.131140
# 6        L4_unc4(e2323)         7.0    7500.0     116.231430
# 7        L4_unc4(e2323)         7.0    7500.0      76.494003
# 8        L4_unc4(e2323)         7.0    3690.0      43.693333
# 9        L4_unc4(e2323)        10.0    7500.0       0.842387
# 10       L4_unc4(e2323)        10.0    7500.0       0.920853
# 11       L4_unc4(e2323)        10.0    1175.0       1.014452
# 12       L4_unc4(e2323)        23.0    1125.0       0.722098
# 13       L4_unc4(e2323)        28.0    1800.0       0.733691
# 14       L4_unc4(e2323)        35.0    4300.0       0.751748
# 15       L4_unc4(e2323)        44.0    2108.0       0.794961
# 16       L4_unc4(e2323)        54.0    1425.0       0.940863
# 17       L4_unc4(e2323)        84.0     625.0       0.841905
# 18       L4_unc4(e2323)       112.0     575.0       0.878049
# 19       L4_unc4(e2323)       126.0     150.0       3.010000
# 20       L4_unc4(e2323)       129.0    1350.0       0.944342
# 21       L4_unc4(e2323)       144.0     800.0       0.784400
# 22       L4_unc4(e2323)       171.0     450.0       0.763894
# 23       L4_unc4(e2323)       199.0    1050.0       0.828943
# 24       L4_unc4(e2323)       228.0    1025.0       0.800163
# 25       L4_unc4(e2323)       231.0     575.0       0.698701
# 26       L4_unc4(e2323)       252.0     125.0       1.632727
# 27       L4_unc4(e2323)       254.0    7500.0       0.892618
# 28       L4_unc4(e2323)       254.0    4665.0       0.995714
# 29       L4_unc4(e2323)       262.0     550.0       0.869752
# 30       L4_unc4(e2323)       356.0     225.0       0.983415
# 0           unc4(e2323)         1.0    1414.0       1.349721
# 1           unc4(e2323)         2.0    7500.0       2.496433
# 2           unc4(e2323)         2.0     391.0       1.054167
# 3           unc4(e2323)         3.0    1050.0       1.061875
# 4           unc4(e2323)         4.0    1050.0       1.617714
# 5           unc4(e2323)         5.0    7500.0       2.008725
# 6           unc4(e2323)         5.0    7500.0       1.685763
# 7           unc4(e2323)         5.0    7500.0       1.831735
# 8           unc4(e2323)         5.0    7500.0       1.571182
# 9           unc4(e2323)         5.0    7500.0      19.015064
# 10          unc4(e2323)         5.0    3657.0      47.376472
# 11          unc4(e2323)        17.0    5908.0       1.630892
# 12          unc4(e2323)        18.0    1075.0       0.944427
# 13          unc4(e2323)        20.0    7500.0       2.427423
# 14          unc4(e2323)        20.0    7500.0       1.413512
# 15          unc4(e2323)        20.0    1398.0       0.996426
# 16          unc4(e2323)        21.0    5954.0       1.221578
# 17          unc4(e2323)        39.0     479.0       2.122500
# 18          unc4(e2323)        40.0     138.0       0.788421
# 19          unc4(e2323)        41.0    3474.0       6.742385
# 20          unc4(e2323)        42.0    3474.0       1.584023
# 21          unc4(e2323)        52.0     154.0       1.903333
# 22          unc4(e2323)        56.0    7500.0       9.555629
# 23          unc4(e2323)        56.0    7500.0      47.254444
# 24          unc4(e2323)        56.0    7500.0      64.881599
# 25          unc4(e2323)        56.0    2143.0      32.662857
# 26          unc4(e2323)        58.0    5175.0       1.123508
# 27          unc4(e2323)        60.0     336.0       2.246250
# 28          unc4(e2323)        61.0     336.0       1.271034
# 29          unc4(e2323)        63.0    7500.0       1.309385
# 30          unc4(e2323)        63.0    7500.0       1.041818
# 31          unc4(e2323)        63.0     192.0       0.742857
# 32          unc4(e2323)        64.0    7500.0       2.473099
# 33          unc4(e2323)        64.0    7500.0       1.157858
# 34          unc4(e2323)        64.0     192.0       0.903830
# 35          unc4(e2323)        67.0     750.0       0.751963
# 36          unc4(e2323)        70.0    7500.0       1.389511
# 37          unc4(e2323)        70.0     175.0       0.742609
# 0   L4_unc4(e2323)ceh12         1.0    7500.0      36.667274
# 1   L4_unc4(e2323)ceh12         1.0    7500.0      87.863159
# 2   L4_unc4(e2323)ceh12         1.0    7500.0     157.283997
# 3   L4_unc4(e2323)ceh12         1.0    7500.0      54.700741
# 4   L4_unc4(e2323)ceh12         1.0    7500.0      92.722221
# 5   L4_unc4(e2323)ceh12         1.0    3635.0      71.938179
# 6   L4_unc4(e2323)ceh12         2.0    1885.0       1.549152
# 7   L4_unc4(e2323)ceh12         4.0    1885.0       3.027302
# 8   L4_unc4(e2323)ceh12         7.0    7500.0       1.318280
# 9   L4_unc4(e2323)ceh12         7.0    7500.0       1.159845
# 10  L4_unc4(e2323)ceh12         7.0    7500.0      17.914000
# 11  L4_unc4(e2323)ceh12         7.0    2679.0       4.975619
# 12  L4_unc4(e2323)ceh12         8.0    7500.0     110.978462
# 13  L4_unc4(e2323)ceh12         8.0    7500.0      39.207806
# 14  L4_unc4(e2323)ceh12         8.0    7500.0      37.256744
# 15  L4_unc4(e2323)ceh12         8.0    7500.0      83.410530
# 16  L4_unc4(e2323)ceh12         8.0    7500.0      39.790527
# 17  L4_unc4(e2323)ceh12         8.0    2679.0      56.212002
# 18  L4_unc4(e2323)ceh12        11.0    7500.0       2.229353
# 19  L4_unc4(e2323)ceh12        11.0    7500.0       1.828623
# 20  L4_unc4(e2323)ceh12        11.0    7500.0       1.547102
# 21  L4_unc4(e2323)ceh12        11.0    7500.0       1.553776
# 22  L4_unc4(e2323)ceh12        11.0    7500.0       1.486752
# 23  L4_unc4(e2323)ceh12        11.0    1712.0       1.738990
# 24  L4_unc4(e2323)ceh12        12.0    7500.0       1.331820
# 25  L4_unc4(e2323)ceh12        12.0    3494.0       1.630725
# 26  L4_unc4(e2323)ceh12        15.0    7500.0       1.824272
# 27  L4_unc4(e2323)ceh12        15.0    7500.0       1.837188
# 28  L4_unc4(e2323)ceh12        15.0    3575.0       1.645416
# 29  L4_unc4(e2323)ceh12        21.0    2975.0       2.195175
# 30  L4_unc4(e2323)ceh12        26.0    2610.0       1.969451
# 0      unc4(e2323)ceh12         1.0    7500.0       2.364071
# 1      unc4(e2323)ceh12         1.0    1252.0       2.626250
# 2      unc4(e2323)ceh12         2.0    7500.0       1.122714
# 3      unc4(e2323)ceh12         2.0    1611.0       0.898788
# 4      unc4(e2323)ceh12         3.0    7500.0       0.945077
# 5      unc4(e2323)ceh12         3.0    7500.0       0.930457
# 6      unc4(e2323)ceh12         3.0    4704.0       0.918932
# 7      unc4(e2323)ceh12         5.0    3400.0       0.934075
# 8      unc4(e2323)ceh12        57.0    7500.0       0.790263
# 9      unc4(e2323)ceh12        57.0    7500.0       0.792559
# 10     unc4(e2323)ceh12        57.0    3430.0       0.854053
# 11     unc4(e2323)ceh12        59.0    3171.0       1.632174
# 12     unc4(e2323)ceh12        77.0     339.0       0.818391
# 13     unc4(e2323)ceh12        88.0    7500.0       0.990379
# 14     unc4(e2323)ceh12        88.0    7500.0       0.921740
# 15     unc4(e2323)ceh12        88.0    1532.0       0.942135
# 16     unc4(e2323)ceh12        89.0    5651.0       2.896667
# 17     unc4(e2323)ceh12        95.0    7500.0       1.387333
# 18     unc4(e2323)ceh12        95.0    2029.0       3.794839
# 19     unc4(e2323)ceh12       144.0    7500.0       1.624695
# 20     unc4(e2323)ceh12       144.0    7500.0       1.023475
# 21     unc4(e2323)ceh12       144.0    5863.0       0.915244
# 22     unc4(e2323)ceh12       145.0    1722.0       0.823636
# 23     unc4(e2323)ceh12       162.0    7500.0       0.890610
# 24     unc4(e2323)ceh12       162.0    1839.0       0.885217
# 25     unc4(e2323)ceh12       163.0    3854.0       0.882149
# 26     unc4(e2323)ceh12       182.0    2958.0       0.949371
# 27     unc4(e2323)ceh12       184.0    7500.0       0.859504
# 28     unc4(e2323)ceh12       184.0    2612.0       0.814510
# 29     unc4(e2323)ceh12       208.0    2563.0       1.234829
# 30     unc4(e2323)ceh12       217.0    1525.0       0.824457
# 31     unc4(e2323)ceh12       226.0    4825.0       0.968692
# 32     unc4(e2323)ceh12       241.0    6746.0       0.884154
# 33     unc4(e2323)ceh12       273.0    3221.0       1.034722
# 34     unc4(e2323)ceh12       277.0    2961.0       0.826145

# %%
print(grouped.aggregate({'worm_index':len}))
# Out:
#                      worm_index
# base_name
# L4_unc4(e2323)             31.0
# L4_unc4(e2323)ceh12        31.0
# unc4(e2323)                38.0
# unc4(e2323)ceh12           35.0

# %%
import matplotlib.pylab as plt

lab_oder = sorted(medians_split['base_name'].unique())
lab_oder = ['L4_unc4(e2323)', 'L4_unc4(e2323)ceh12', 'unc4(e2323)', 'unc4(e2323)ceh12']

for icol, col in enumerate(feat_cols):
    if icol % 5==0:
        plt.figure(figsize=(20,4))
    plt.subplot(1, 5, (icol%5)+1)
    ax =sns.swarmplot(x="base_name", y=col, hue='worm_index', data=medians_split, order=lab_oder)
    ax.legend_.remove()
    for item in ax.get_xticklabels():
        item.set_rotation(90)
    #if icol > 200:
    #    break

# %%
import matplotlib.pylab as plt

lab_oder = ['L4_unc4(e2323)', 'L4_unc4(e2323)ceh12', 'unc4(e2323)', 'unc4(e2323)ceh12']

for icol, col in enumerate([x for x in feat_cols if 'backward' in x]):
    if icol % 5==0:
        plt.figure(figsize=(20,4))
    plt.subplot(1, 5, (icol%5)+1)
    ax =sns.swarmplot(x="base_name", y=col, hue='worm_index', data=medians_split, order=lab_oder)
    ax.legend_.remove()
    for item in ax.get_xticklabels():
        item.set_rotation(90)
# Out:
# /Users/ajaver/miniconda/lib/python3.5/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
